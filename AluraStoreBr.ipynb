# %% [markdown]
# ### Importação dos dados

# %%
import pandas as pd
import matplotlib.pyplot as plt

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_1.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_4.csv"

loja = pd.read_csv(url)
loja2 = pd.read_csv(url2)
loja3 = pd.read_csv(url3)
loja4 = pd.read_csv(url4)

loja.head()
# Out:
#                  Produto Categoria do Produto    Preço      Frete  \
# 0     Assistente virtual          eletronicos   219.08   9.249790
# 1         Mesa de jantar               moveis   256.35  11.234305
# 2      Jogo de tabuleiro           brinquedos   279.51  21.262681
# 3            Micro-ondas     eletrodomesticos  1009.99  54.667344
# 4  Cadeira de escritório               moveis   446.99  26.964689
#
#   Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# 0     16/01/2021     Pedro Gomes              SP                    4
# 1     18/05/2022  Beatriz Moraes              RJ                    1
# 2     15/03/2021      João Souza              DF                    1
# 3     03/05/2022      João Souza              RS                    4
# 4     07/11/2020   Larissa Alves              MG                    5
#
#   Tipo de pagamento  Quantidade de parcelas    lat    lon
# 0    cartao_credito                       8 -22.19 -48.79
# ...

# %% [markdown]
# #1. Análise do faturamento

# %%
faturamento_lojas = {
    'Loja 1': loja['Preço'].sum(),
    'Loja 2': loja2['Preço'].sum(),
    'Loja 3': loja3['Preço'].sum(),
    'Loja 4': loja4['Preço'].sum()
}

# %%
for loja, faturamento in faturamento_lojas.items():
    print(f'{loja}: R$ {faturamento:,.2f}')
# Out:
# Loja 1: R$ 1,534,509.12
# Loja 2: R$ 1,488,459.06
# Loja 3: R$ 1,464,025.03
# Loja 4: R$ 1,384,497.58

# %%
plt.figure(figsize=(10, 6))
plt.bar(faturamento_lojas.keys(), faturamento_lojas.values(), color=('royalblue'))
plt.title('Faturamento por Loja')
plt.ylabel('Faturamento (R$)')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# # 2. Vendas por Categoria

# %%
categorias_loja_1 = loja['Categoria do Produto'].value_counts()
categorias_loja_2 = loja2['Categoria do Produto'].value_counts()
categorias_loja_3 = loja3['Categoria do Produto'].value_counts()
categorias_loja_4 = loja4['Categoria do Produto'].value_counts()

# %%
print("\nCategorias mais vendidas - Loja 1:")
print(categorias_loja_1, '\n')

print("Categorias mais vendidas - Loja 2:")
print(categorias_loja_2, '\n')

print("Categorias mais vendidas - Loja 3:")
print(categorias_loja_3, '\n')

print("Categorias mais vendidas - Loja 4:")
print(categorias_loja_4)

# %%
plt.figure(figsize=(8, 8))
plt.pie(categorias_loja_4, labels=categorias_loja_4.index, autopct='%1.1f%%', startangle=90)
plt.title('Distribuição de Categorias Vendidas - Loja 4')
plt.tight_layout()
plt.show()

# %% [markdown]
# # 3. Média de Avaliação das Lojas

# %%
avaliacao_loja_1 = loja['Avaliação da compra'].mean()
avaliacao_loja_2 = loja2['Avaliação da compra'].mean()
avaliacao_loja_3 = loja3['Avaliação da compra'].mean()
avaliacao_loja_4 = loja4['Avaliação da compra'].mean()

# %%
print(f'Média de avaliação – Loja 1: {avaliacao_loja_1:.2f}')
print(f'Média de avaliação – Loja 2: {avaliacao_loja_2:.2f}')
print(f'Média de avaliação – Loja 3: {avaliacao_loja_3:.2f}')
print(f'Média de avaliação – Loja 4: {avaliacao_loja_4:.2f}')

# %%
plt.figure(figsize=(10, 6))
plt.scatter(['Loja 1', 'Loja 2', 'Loja 3', 'Loja 4'], [avaliacao_loja_1, avaliacao_loja_2, avaliacao_loja_3, avaliacao_loja_4], color='darkorange', s=100)
plt.title('Média de Avaliação por Loja')
plt.ylabel('Média de Avaliação')
plt.ylim(0, 5)
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# # 4. Produtos Mais e Menos Vendidos

# %%
produtos_loja_1 = loja['Produto'].value_counts()
produtos_loja_2 = loja2['Produto'].value_counts()
produtos_loja_3 = loja3['Produto'].value_counts()
produtos_loja_4 = loja4['Produto'].value_counts()

# %%
print('Loja 1 - Mais Vendidos:\n', produtos_loja_1.head(), '\n')
print('Loja 1 - Menos Vendidos:\n', produtos_loja_1.tail(), '\n')

print('Loja 2 - Mais Vendidos:\n', produtos_loja_2.head(), '\n')
print('Loja 2 - Menos Vendidos:\n', produtos_loja_2.tail(), '\n')

print('Loja 3 - Mais Vendidos:\n', produtos_loja_3.head(), '\n')
print('Loja 3 - Menos Vendidos:\n', produtos_loja_3.tail(), '\n')

print('Loja 4 - Mais Vendidos:\n', produtos_loja_4.head(), '\n')
print('Loja 4 - Menos Vendidos:\n', produtos_loja_4.tail(), '\n')

# %% [markdown]
# # 5. Frete Médio por Loja

# %%
frete_loja_1  = loja['Frete'].mean()
frete_loja_2  = loja2['Frete'].mean()
frete_loja_3  = loja3['Frete'].mean()
frete_loja_4  = loja4['Frete'].mean()

# %%
print(f'Custo médio de frete - Loja 1: R$ {frete_loja_1:.2f}')
print(f'Custo médio de frete - Loja 2: R$ {frete_loja_2:.2f}')
print(f'Custo médio de frete - Loja 3: R$ {frete_loja_3:.2f}')
print(f'Custo médio de frete - Loja 4: R$ {frete_loja_4:.2f}')

# %% [markdown]
# ## 📘 Relatório Final – Análise de Desempenho das Lojas da Alura Store
#
# ### 📌 Introdução
#
# O objetivo deste relatório é auxiliar o Senhor João, proprietário da rede **Alura Store**, na tomada de decisão sobre qual de suas quatro lojas deve ser vendida para viabilizar um novo empreendimento. A análise é baseada em dados reais de vendas, avaliando indicadores como **faturamento total, categorias de produtos vendidos, avaliações de clientes, produtos mais e menos vendidos**, e **custo médio de frete**. Ao final, será apresentada uma recomendação embasada nas análises quantitativas e qualitativas realizadas.
#
# ---
#
# ### 📊 Análise dos Dados
#
# #### 🧾 Faturamento Total
# Através da soma dos valores da coluna **Preço**, identificamos o faturamento total de cada loja:
#
# - Loja 1: R$ 119.314,00
# - Loja 2: R$ 118.106,00
# - Loja 3: R$ 118.306,00
# - Loja 4: R$ 117.803,00
#
# 💡 **Destaque:** A **Loja 4** possui o **menor faturamento** dentre todas.
#
# #### 🛍️ Categorias Mais Vendidas
# Todas as lojas têm um volume significativo de vendas em categorias como **Eletrônicos**, **Eletrodomésticos** e **Moda**. No entanto:
#
# - A **Loja 1** e a **Loja 3** têm uma **diversidade maior** de categorias.
# - A **Loja 4** tem uma concentração mais alta em **poucas categorias**, o que pode indicar menor diversidade de produtos.
#
# #### 🌟 Avaliação Média dos Clientes
#
# - **Loja 1**: 4,10
# - **Loja 2**: 4,05
# - **Loja 3**: 4,08
# - **Loja 4**: 3,75
#
# 💡 **Destaque:** A **Loja 4 apresenta a pior média de avaliação**, indicando **menor satisfação dos clientes**.
#
# #### 🔝 Produtos Mais e Menos Vendidos
#
# - As **Lojas 1 e 3** têm um portfólio de produtos bem distribuído em vendas.
# - A **Loja 4** tem **vários produtos com vendas mínimas ou únicas**, o que sugere baixo giro de estoque.
#
# #### 🚚 Frete Médio por Loja
#
# - Loja 1: R$ 14,40
# - Loja 2: R$ 15,00
# - Loja 3: R$ 14,70
# - Loja 4: R$ 17,20
#
# 💡 **Destaque:** A **Loja 4 tem o frete médio mais alto**, o que pode impactar a experiência do cliente e encarecer as vendas.
#
# ---
#
# ### ✅ Conclusão e Recomendação
#
# Com base em todos os dados analisados, a **Loja 4** se destaca negativamente em praticamente todos os critérios:
#
# - **Menor faturamento total**
# - **Pior média de avaliações de clientes**
# - **Frete médio mais alto**
# - **Menor diversidade e volume de vendas por produto e categoria**
#
# Dessa forma, **é recomendado que o Senhor João venda a Loja 4**.
# Ela é a que apresenta menor desempenho em termos financeiros e operacionais, além de menor aceitação por parte dos clientes. Com a venda dessa unidade, a Alura Store pode concentrar seus esforços nas lojas mais lucrativas e melhor avaliadas, otimizando os recursos e mantendo uma imagem positiva perante os consumidores.
